# %%
import numpy as numpy
import  requests
import pandas as pd
from bs4 import BeautifulSoup
#url = "https://www.amazon.com/Sony-PlayStation-Pro-1TB-Console-4/dp/B07K14XKZH/"
url = "https://www.amazon.in/s?k=baby+milk&ref=nb_sb_noss"
#url ="https://www.amazon.com/Playstation-Included-Spider-Man-Ghost-Manta/dp/B0891LH1D7/ref=sr_1_2_sspa?dchild=1&keywords=playstation+4&qid=1609686625&sr=8-2-spons&psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUExSENKSEJaUDk2U1A3JmVuY3J5cHRlZElkPUExMDQzMzM5Mzk0NDZDM0dEN1dCQSZlbmNyeXB0ZWRBZElkPUEwNTY0ODY1MUs2OEpFWkY3UktaRyZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU="
#url ="https://www.flipkart.com/search?q=kurtis&sid=clo%2Ccfv%2Ccib%2Crkt&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=kurtis%7CWomen%27s+Kurtas&requestId=22c9d084-f985-4e35-beba-1c3308cbf39d"
headers = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
r = requests.get(url,headers=headers)
print(r)
# Out:
# <Response [200]>

# %%
htmlcontent = r.content
soup = BeautifulSoup(htmlcontent, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
anchor_same_class  =  soup.find('td') # to find specific class inside anchor tag
print(anchor_same_class)
# Out:
# <td class="rhf-loading-inner">
# <img src="https://images-eu.ssl-images-amazon.com/images/G/31/personalization/ybh/loading-4x-gray._CB485916689_.gif"/>
# </td>

# %%
price = soup.select("#productTitle")
print(price)
# Out:
# []

# %%
links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
print(links)
# Out:
# [<a class="a-link-normal s-no-outline" href="/Nestle-Lactogen-Infant-Formula-Powder/dp/B00I4SZLNG/ref=sr_1_1?dchild=1&amp;keywords=baby+milk&amp;qid=1610268813&amp;sr=8-1" target="_blank">
# <div class="a-section aok-relative s-image-fixed-height">
# <img alt="Nestlé LACTOGEN 1 Infant Formula Powder (Up to 6 months), Stage 1 - 400g Bag-In-Box Pack" class="s-image" data-image-index="1" data-image-latency="s-product-image" data-image-load="" data-image-source-density="1" src="https://m.media-amazon.com/images/I/71k1IHYUKvL._AC_UY218_.jpg" srcset="https://m.media-amazon.com/images/I/71k1IHYUKvL._AC_UY218_.jpg 1x, https://m.media-amazon.com/images/I/71k1IHYUKvL._AC_UY327_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/71k1IHYUKvL._AC_UY436_QL65_.jpg 2x, https://m.media-amazon.com/images/I/71k1IHYUKvL._AC_UY545_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/71k1IHYUKvL._AC_UY654_QL65_.jpg 3x"/>
# </div>
# ...

# %%
links_list = []
for link in links:
    links_list.append(link.get('href'))
    print(link.get('href'))
    print()
    
        
#print(links_list)
# Out:
# /Nestle-Lactogen-Infant-Formula-Powder/dp/B00I4SZLNG/ref=sr_1_1?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-1
#
# /Nestl%C3%A9-Lactogen-Infant-Formula-Powder/dp/B01H4UQY3K/ref=sr_1_2?dchild=1&fpw=pantry&keywords=baby+milk&qid=1610268813&s=pantry&sr=8-2
#
# /Enfamil-Powder-Nutritional-Health-Formula/dp/B07PX2JC6H/ref=sr_1_3?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-3
#
# /Maxima-Aayush-Stainless-Feeding-Bottle/dp/B0837QY4R4/ref=sr_1_4?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-4
#
# /Stainless-Feeding-Colorful-Graphics-Internal/dp/B08PQ3JBGX/ref=sr_1_5?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-5
#
# /NEXT-ANGLE-STOREMART-Vaporizer-Multicolor/dp/B08C5FMHGG/ref=sr_1_6?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-6
#
# /CHILDCHIC-Feeding-Bottle-Thermo-Steel-Multifunctional-Sipper/dp/B08PZ8RCRX/ref=sr_1_7?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-7
#
# ...

# %%
def get_title(soup):
    try:
        title_string = soup.find("span", attrs={"class":'a-size-large product-title-word-break'}).string.strip()
        #title_value = title.string
        #title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    #print(title_string)
        
    return title_string

def get_price(soup):
    try:
        price = soup.find("span", attrs={"id":'priceblock_ourprice'})
        price_value = price.string
        price_string = price_value.strip()
    except AttributeError:
        try:
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
            price_value = price.string
            price_string = price_value.strip()
        except:
            price_string = ''
    return price_string

def get_rating(soup):
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    except:
        rating = ''
    return rating

def get_description(soup):
    try:
        desc = soup.find_all('div', attrs={'id':'productDescription'})
    except:
        desc = ''
    return desc


        
            
for link in links_list:
    new_webpage  = requests.get("https://www.amazon.in" + link, headers=headers)
    new_soup = BeautifulSoup(new_webpage.content, "lxml")
    print("----tilte= " ,get_title(new_soup))
    print("price  = ",get_price(new_soup) )
    print("rating  = ",get_rating(new_soup) )
    print("Description = ", get_description(new_soup))
    print()
# Out:
# ----tilte=  Nestlé LACTOGEN 1 Infant Formula Powder (Up to 6 months), Stage 1 - 400g Bag-In-Box Pack
# price  =  ₹ 330.00
# rating  =  4.4 out of 5 stars
# Description =  []
#
# ----tilte=  Nestlé LACTOGEN 1 Infant Formula Powder - Upto 6 months, Stage 1, 400g BIB Pack
# price  =  ₹ 330.00
# rating  =  4.5 out of 5 stars
# Description =  []
#
# ----tilte=  Enfamil A+ Baby Milk Powder Nutritional Health Drink Infant Formula – Stage 1 (0-6 months) (400g x 2)
# price  =  ₹ 1,430.00
# rating  =  4.3 out of 5 stars
# Description =  []
#
# ----tilte=  Maxima Aayush Stainless Steel Baby Feeding Bottle, Milk Feeding, Water Feeding 250 ml.
# price  =  ₹ 345.00
# rating  =
# Description =  []
#
# ----tilte=
# price  =
# rating  =
# Description =  []
#
# ----tilte=  NEXT ANGLE STOREMART Made in India 3 in 1 Steam Vaporizer Health Care Bottle Feeder Warmer Facial Steamer for Women Use, Baby Use, Parlor, Salon (Multicolor)
# price  =  ₹ 599.00
# rating  =
# Description =  []
#
# ----tilte=
# ...

# %%
new_webpage  = requests.get("https://www.amazon.in/Nestl%C3%A9-Lactogen-Infant-Formula-Powder/dp/B01H4UQY3K/ref=sr_1_2?dchild=1&fpw=pantry&keywords=baby+milk&qid=1610202530&s=pantry&sr=8-2" , headers=headers)
new_soup = BeautifulSoup(new_webpage.content, "lxml")
title_string = new_soup.find("span", attrs={"id":'productTitle'})
print(title_string)
# Out:
# None

# %%
for link in links_list:
    url = "https://www.amazon.in" + link
    new_webpage  = requests.get(url, headers=headers)
    new_soup = BeautifulSoup(new_webpage.content, "lxml")
    if get_title(new_soup) !='':
        print(url,"----tilte= " ,get_title(new_soup))
    print()
# Out:
# https://www.amazon.in/Nestle-Lactogen-Infant-Formula-Powder/dp/B00I4SZLNG/ref=sr_1_1?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-1 ----tilte=  Nestlé LACTOGEN 1 Infant Formula Powder (Up to 6 months), Stage 1 - 400g Bag-In-Box Pack
#
#
#
#
#
#
# https://www.amazon.in/CHILDCHIC-Feeding-Bottle-Thermo-Steel-Multifunctional-Sipper/dp/B08PZ8RCRX/ref=sr_1_7?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-7 ----tilte=  CHILDCHIC 3 in 1 Baby Feeding Bottle Thermo-Steel Multifunctional-Sipper;Nipple & Straw 240 ML;Baby Feeding Bottle;Baby Milk Feeding Bottle;Water Feeding Bottle (Blue)
#
# https://www.amazon.in/Modicare-Baby-Cream-Vitamin-Protein-50gm/dp/B08CRS62XZ/ref=sr_1_8?dchild=1&keywords=baby+milk&qid=1610268813&sr=8-8 ----tilte=  Modicare Baby SPA Milk Cream with Vitamin E, B5 & Milk Protein-50gm each (Pack of 2)
#
#
#
#
#
# ...

# %%
def get_title(soup):
    try:
        title_string = soup.find("span", attrs={"id":'productTitle'})
        #title_value = title.string
        #title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    #print(title_string)
        
    return title_string
url = "https://www.amazon.in/BAYBEE-Sterilizer-Electric-Defrost-Feeding/dp/B08LQKW1YT/ref=sr_1_10?dchild=1&keywords=baby+milk&qid=1610217215&sr=8-10" 
new_webpage  = requests.get(url, headers=headers)
new_soup = BeautifulSoup(new_webpage.content, "lxml")
print(url,"----tilte= " ,get_title(new_soup))
ss =  new_soup.find("span", attrs={"class":'a-size-large product-title-word-break'})
print(ss)
print()
# Out:
# https://www.amazon.in/BAYBEE-Sterilizer-Electric-Defrost-Feeding/dp/B08LQKW1YT/ref=sr_1_10?dchild=1&keywords=baby+milk&qid=1610217215&sr=8-10 ----tilte=  None
# None

# %%
mm = "https://www.amazon.in/Nestle-Lactogen-Infant-Formula-Powder/dp/B00I4SZLNG/ref=sr_1_1?dchild=1&keywords=baby+milk&qid=1610209093&sr=8-1"
new_webpage  = requests.get(mm, headers=headers)
new_soup = BeautifulSoup(new_webpage.content, "html.parser")
test_string = new_soup.find("span", attrs={"id":'productTitle'})
print(test_string)
# Out:
# None

# %%
mm = "https://www.amazon.in/Nestl%C3%A9-Lactogen-Infant-Formula-Powder/dp/B01H4UQY3K/ref=sr_1_2?dchild=1&fpw=pantry&keywords=baby+milk&qid=1610209093&s=pantry&sr=8-2"
new_webpage  = requests.get(mm, headers=headers)
new_soup = BeautifulSoup(new_webpage.content, "html.parser")
test_string = new_soup.find("span", attrs={"id":'productTitle'})
print(test_string)
# Out:
# <span class="a-size-large product-title-word-break" id="productTitle">
#
#
#
#
#
#
#
# Nestlé LACTOGEN 1 Infant Formula Powder - Upto 6 months, Stage 1, 400g BIB Pack
#
#
#
#
#
#
# </span>

# %%
def get_title(soup):
     
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
 
        # Inner NavigatableString Object
        title_value = title.string
 
        # Title as a string value
        title_string = title_value.strip()
 
        # # Printing types of values for efficient understanding
        # print(type(title))
        # print(type(title_value))
        # print(type(title_string))
        # print()
 
    except AttributeError:
        title_string = ""   
 
    return title_string
 
# Function to extract Product Price
def get_price(soup):
 
    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()
 
    except AttributeError:
 
        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
 
        except:     
            price = ""  
 
    return price
 
# Function to extract Product Rating
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
 
# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
 
# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
 
    except AttributeError:
        available = "Not Available"
 
    return available    
 
 
if __name__ == '__main__':
 
    # Headers for request
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Accept-Language': 'en-US'})
 
    # The webpage URL
    URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"
     
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "lxml")
 
    # Fetch links as List of Tag Objects
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
 
    # Store the links
    links_list = []
 
    # Loop for extracting links from Tag Objects
    for link in links:
        links_list.append(link.get('href'))
 
 
    # Loop for extracting product details from each link 
    for link in links_list:
 
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
 
        new_soup = BeautifulSoup(new_webpage.content, "lxml")
         
        # Function calls to display all necessary product information
        print("Product Title =", get_title(new_soup))
        print("Product Price =", get_price(new_soup))
        print("Product Rating =", get_rating(new_soup))
        print("Number of Product Reviews =", get_review_count(new_soup))
        print("Availability =", get_availability(new_soup))
        print()
        print()
